# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %pip install openpyxl

# %%
data = pd.read_excel('hw-01-class-data.xlsx')
data
# Out:
#     In which country were you born? In which city were you born?  \
# 0                               NaN                          NaN
# 1                     United States      Los Angeles, California
# 2                       Netherlands                      Haarlem
# 3                     United States          Rockville, Maryland
# 4                     United States                      Warwick
# ..                              ...                          ...
# 102                        Ethiopia                  Addis Abeba
# 103                             USA                      Yonkers
# 104        United States of America                      Chicago
# 105                           India                    Hyderabad
# 106                   United States             Colorado Springs
#
#     In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).   \
# 0                                                  NaN
# 1                                              English
# 2                                       Dutch, English
# 3                                      English, Korean
# 4                                              English
# ..                                                 ...
# 102                                   English, Amharic
# 103                                    English, Korean
# 104                                   English, Spanish
# 105                                   English, Telugu
# 106                                            Spanish
#
#                      Which is your preferred OS?  \
# 0                                            NaN
# 1                                          Apple
# 2                                        Windows
# 3                                        Windows
# 4                                        Windows
# ..                                           ...
# 102                                      Windows
# 103                                      Windows
# 104  Use Apple a lot, but more versed on windows
# 105                                        Apple
# 106                                      Windows
#
#     Which is your preferred mobile OS?  \
# 0                                  NaN
# 1                            Apple iOS
# 2                            Apple iOS
# 3                            Apple iOS
# 4                            Apple iOS
# ..                                 ...
# 102                          Apple iOS
# 103                          Apple iOS
# 104                          Apple iOS
# 105                          Apple iOS
# 106                          Apple iOS
#
#     What field(s) do you think can benefit the most from visualization? (If you have multiple answers, please separate them with a comma)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                           Journalism
# 3                                           Philosophy
# 4                                              Finance
# ..                                                 ...
# 102       I would be interested in using it for design
# 103  I think data and business analysts can benefit...
# 104                      Public Service, Finance, Tech
# 105                                 Marketing, Politcs
# 106                       Machine Learning, Healthcare
#
#     Please rank the animals you like most in the following list.   [First Choice]  \
# 0                                                  NaN
# 1                                      Flying squirrel
# 2                                           Sea Turtle
# 3                                              Dolphin
# 4                                                  Dog
# ..                                                 ...
# 102                                           Elephant
# 103                                                Dog
# 104                                                Cat
# 105                                              Llama
# 106                                                Dog
#
#     Please rank the animals you like most in the following list.   [Second Choice]  \
# 0                                                  NaN
# 1                                              Dolphin
# 2                                             Hedgehog
# 3                                                  Dog
# 4                                             Elephant
# ..                                                 ...
# 102                                                Cat
# 103                                                Cat
# 104                                            Dolphin
# 105                                                Cat
# 106                                    Flying squirrel
#
#     Please rank the animals you like most in the following list.   [Third Choice ]  \
# 0                                                  NaN
# 1                                                  Cat
# 2                                                  Dog
# 3                                           Sea Turtle
# 4                                              Dolphin
# ..                                                 ...
# 102                                         Sea Turtle
# 103                                              Moose
# 104                                    Flying squirrel
# 105                                           Elephant
# 106                                            Dolphin
#
#     What is your favorite color? What is your favorite number?  \
# 0                            NaN                           NaN
# 1                           Blue                            97
# 2                           Blue                             8
# 3                          Green                             9
# 4                           Blue                             3
# ..                           ...                           ...
# 102                       Yellow                             8
# 103                         Blue                            11
# 104                          Red                             8
# 105                       Orange                            21
# 106                Sunset orange                            13
#
#     What temperature is it outside right now? (In Celsius)   \
# 0                                                  NaN
# 1                                                    2
# 2                                                    1
# 3                                                  NaN
# 4                                                    3
# ..                                                 ...
# 102                                               24 F
# 103                                                 -9
# 104                                                -10
# 105                                             -11.11
# 106                                                  8
#
#     On average, how many cups of coffee do you drink each day?  \
# 0                                                  NaN
# 1                                                    0
# 2                                                    1
# 3                                                  0.5
# 4                                                    1
# ..                                                 ...
# 102                                                  0
# 103                                                  0
# 104                                                1.5
# 105                                                0.3
# 106                                                  0
#
#     What time do you typically wake up?   \
# 0                                    NaN
# 1                               10:00:00
# 2                               08:00:00
# 3                               08:00:00
# 4                               09:00:00
# ..                                   ...
# 102                             08:00:00
# 103                             10:00:00
# 104                             08:00:00
# 105                             11:00:00
# 106                             05:00:00
#
#     What time do you typically go to bed?   \
# 0                                      NaN
# 1                                 00:00:00
# 2                                 12:00:00
# 3                                 00:00:00
# 4                                 01:00:00
# ..                                     ...
# 102                               00:00:00
# 103                               03:00:00
# 104                               01:00:00
# 105                               02:30:00
# 106                               21:00:00
#
#                  What is your favorite visualization?
# 0                                                  NaN
# 1                                                  NaN
# 2    I'm not sure. FiveThirtyEight.com does cool vi...
# 3                                           Pie Charts
# 4                                                 Maps
# ..                                                 ...
# 102                                polls on map of USA
# 103                                          Histogram
# 104  Object based, whether it be a map with specifi...
# 105                        The kobe bryant shot chart.
# 106                                           A mosaic
#
# [107 rows x 16 columns]

# %%
data.dtypes
# Out:
# In which country were you born?                                                                                                          object
# In which city were you born?                                                                                                             object
# In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).                           object
# Which is your preferred OS?                                                                                                              object
# Which is your preferred mobile OS?                                                                                                       object
# What field(s) do you think can benefit the most from visualization? (If you have multiple answers, please separate them with a comma)    object
# Please rank the animals you like most in the following list.   [First Choice]                                                            object
# Please rank the animals you like most in the following list.   [Second Choice]                                                           object
# Please rank the animals you like most in the following list.   [Third Choice ]                                                           object
# What is your favorite color?                                                                                                             object
# What is your favorite number?                                                                                                            object
# What temperature is it outside right now? (In Celsius)                                                                                   object
# On average, how many cups of coffee do you drink each day?                                                                               object
# What time do you typically wake up?                                                                                                      object
# What time do you typically go to bed?                                                                                                    object
# What is your favorite visualization?                                                                                                     object
# dtype: object

# %%
data.shape
# Out:
# (107, 16)

# %%
data.isnull().sum()
# Out:
# In which country were you born?                                                                                                           4
# In which city were you born?                                                                                                              6
# In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).                            6
# Which is your preferred OS?                                                                                                               4
# Which is your preferred mobile OS?                                                                                                        4
# What field(s) do you think can benefit the most from visualization? (If you have multiple answers, please separate them with a comma)    14
# Please rank the animals you like most in the following list.   [First Choice]                                                             4
# Please rank the animals you like most in the following list.   [Second Choice]                                                            4
# Please rank the animals you like most in the following list.   [Third Choice ]                                                            4
# What is your favorite color?                                                                                                              4
# What is your favorite number?                                                                                                             4
# What temperature is it outside right now? (In Celsius)                                                                                    6
# On average, how many cups of coffee do you drink each day?                                                                                4
# What time do you typically wake up?                                                                                                       4
# What time do you typically go to bed?                                                                                                     4
# What is your favorite visualization?                                                                                                     20
# dtype: int64

# %%
# 26 rows with null
data[data.isnull().any(axis=1)].shape
# Out:
# (26, 16)

# %%
for col in data.columns:
    print(col)
# Out:
# In which country were you born?
# In which city were you born?
# In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas).
# Which is your preferred OS?
# Which is your preferred mobile OS?
# What field(s) do you think can benefit the most from visualization? (If you have multiple answers, please separate them with a comma)
# Please rank the animals you like most in the following list.   [First Choice]
# Please rank the animals you like most in the following list.   [Second Choice]
# Please rank the animals you like most in the following list.   [Third Choice ]
# What is your favorite color?
# What is your favorite number?
# What temperature is it outside right now? (In Celsius)
# On average, how many cups of coffee do you drink each day?
# What time do you typically wake up?
# What time do you typically go to bed?
# What is your favorite visualization?

# %%
# lambda function to extract first number in a string
get_nums = lambda x: [float(num) for num in str(x).split() if num.isdigit()]
get_first_num_else_nan = lambda x: x[0] if len(x) > 0 else np.nan

# %%
# Problem row, change to just 7

data['What is your favorite number?'].replace('7 and 2', '7', inplace=True)
data['What is your favorite number?'].replace('Don\'t have one.', np.nan, inplace=True)

# Change to floats
data['What is your favorite number?'] = data['What is your favorite number?'].astype(float)

# %%
# Change to lists of floats and then get first element if it exists
data['What temperature is it outside right now? (In Celsius) '] = data['What temperature is it outside right now? (In Celsius) '].apply(lambda x: [float(num) for num in str(x).split() if num.isdigit()])
data['What temperature is it outside right now? (In Celsius) '] = data['What temperature is it outside right now? (In Celsius) '].apply(lambda x: x[0] if len(x) > 0 else np.nan)

# %%
# Apply same lambda function to extract numbers
data['On average, how many cups of coffee do you drink each day?'] = data['On average, how many cups of coffee do you drink each day?'].apply(get_nums)
data['On average, how many cups of coffee do you drink each day?'] = data['On average, how many cups of coffee do you drink each day?'].apply(get_first_num_else_nan)
data['On average, how many cups of coffee do you drink each day?'].unique()
# Out:
# array([nan,  0.,  1.,  3.,  2.])

# %%
data['What is your favorite color?'].unique()
# Out:
# array([nan, 'Blue', 'Green', 'purple', 'green', 'Purple ', 'Rose gold ',
#        'Red', 'Black', 'Pink', 'blue', 'grey', 'Baby blue', 'Purple',
#        'Orange', 'navy', 'pink', 'Sage Green', 'I like all!', 'Yellow',
#        'Navy', 'Pastel Mint', 'Light blue', 'Purpler', 'red', 'White',
#        'Baby Pink', 'Cerulean', 'Pastel Mint Green', 'Sunset orange'],
#       dtype=object)

# %%
# Renaming columns
data = data.rename(columns={'In which country were you born?': 'Birth Country', 'In which city were you born?': 'Birth City',
                     'In which languages (spoken, not programming!) are you proficient? (Please list languages separated by commas). ': 'Languages Spoken' ,
                     'Which is your preferred OS?': 'Preferred OS' , 'Which is your preferred mobile OS?': 'Preferred Mobile OS' , 
                            'What field(s) do you think can benefit the most from visualization? (If you have multiple answers, please separate them with a comma)': 'Field to Benefit from Vis' ,
                            'Please rank the animals you like most in the following list.   [First Choice]': 'Animal 1' , 
                            'Please rank the animals you like most in the following list.   [Second Choice]': 'Animal 2' , 
                            'Please rank the animals you like most in the following list.   [Third Choice ]': 'Animal 3' ,
                     'What is your favorite color?': 'Favorite Color' , 'What is your favorite number?': 'Favorite Number' , 
                            'What temperature is it outside right now? (In Celsius) ': 'Current Outside Temp (C)' , 
                            'On average, how many cups of coffee do you drink each day?': 'Cups of Coffee Each Day' , 
                            'What time do you typically wake up? ': 'Wake Time' , 
                            'What time do you typically go to bed? ': 'Bed Time' , 
                            'What is your favorite visualization? ': 'Favorite Visualization'})

# %%
# drop rows that are all null/na

data.dropna(axis=0, how='all', inplace=True)

# %%
# Strip whitespace from strings
data.apply(lambda x: x.strip() if type(x) == str else x)
# Out:
#                 Birth Country               Birth City  Languages Spoken  \
# 1               United States  Los Angeles, California           English
# 2                 Netherlands                  Haarlem    Dutch, English
# 3               United States      Rockville, Maryland   English, Korean
# 4               United States                  Warwick           English
# 5               United States              Needham, MA               NaN
# ..                        ...                      ...               ...
# 102                  Ethiopia              Addis Abeba  English, Amharic
# 103                       USA                  Yonkers   English, Korean
# 104  United States of America                  Chicago  English, Spanish
# 105                     India                Hyderabad  English, Telugu
# 106             United States         Colorado Springs           Spanish
#
#                                     Preferred OS Preferred Mobile OS  \
# 1                                          Apple           Apple iOS
# 2                                        Windows           Apple iOS
# 3                                        Windows           Apple iOS
# 4                                        Windows           Apple iOS
# 5                                          Apple           Apple iOS
# ..                                           ...                 ...
# 102                                      Windows           Apple iOS
# 103                                      Windows           Apple iOS
# 104  Use Apple a lot, but more versed on windows           Apple iOS
# 105                                        Apple           Apple iOS
# 106                                      Windows           Apple iOS
#
#                              Field to Benefit from Vis         Animal 1  \
# 1                                                  NaN  Flying squirrel
# 2                                           Journalism       Sea Turtle
# 3                                           Philosophy          Dolphin
# 4                                              Finance              Dog
# 5                                         Data Science         Hedgehog
# ..                                                 ...              ...
# 102       I would be interested in using it for design         Elephant
# 103  I think data and business analysts can benefit...              Dog
# 104                      Public Service, Finance, Tech              Cat
# 105                                 Marketing, Politcs            Llama
# 106                       Machine Learning, Healthcare              Dog
#
#             Animal 2         Animal 3 Favorite Color  Favorite Number  \
# 1            Dolphin              Cat           Blue             97.0
# 2           Hedgehog              Dog           Blue              8.0
# 3                Dog       Sea Turtle          Green              9.0
# 4           Elephant          Dolphin           Blue              3.0
# 5           Elephant            Llama           Blue              3.0
# ..               ...              ...            ...              ...
# 102              Cat       Sea Turtle         Yellow              8.0
# 103              Cat            Moose           Blue             11.0
# 104          Dolphin  Flying squirrel            Red              8.0
# 105              Cat         Elephant         Orange             21.0
# 106  Flying squirrel          Dolphin  Sunset orange             13.0
#
#      Current Outside Temp (C)  Cups of Coffee Each Day Wake Time  Bed Time  \
# 1                         2.0                      0.0  10:00:00  00:00:00
# 2                         1.0                      1.0  08:00:00  12:00:00
# 3                         NaN                      NaN  08:00:00  00:00:00
# 4                         3.0                      1.0  09:00:00  01:00:00
# 5                         3.0                      0.0  09:00:00  00:00:00
# ..                        ...                      ...       ...       ...
# 102                      24.0                      0.0  08:00:00  00:00:00
# 103                       NaN                      0.0  10:00:00  03:00:00
# 104                       NaN                      NaN  08:00:00  01:00:00
# 105                       NaN                      NaN  11:00:00  02:30:00
# 106                       8.0                      0.0  05:00:00  21:00:00
#
#                                 Favorite Visualization
# 1                                                  NaN
# 2    I'm not sure. FiveThirtyEight.com does cool vi...
# 3                                           Pie Charts
# 4                                                 Maps
# 5                                                  NaN
# ..                                                 ...
# 102                                polls on map of USA
# 103                                          Histogram
# 104  Object based, whether it be a map with specifi...
# 105                        The kobe bryant shot chart.
# 106                                           A mosaic
#
# [103 rows x 16 columns]

# %%
data.to_excel('clean_data.xlsx', index=False, sheet_name='Clean Survery Data')
